# %% [markdown]
# <a href="https://colab.research.google.com/github/vapaul10/Business-Multiple-Attributes/blob/Week-5-Homework/Valeri_Paul_DESC_637_Hwk_Week_4_Due_Wk5a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1
#
# Week 4 Homework
#
# Create an Influence Tree

# %% [markdown]
# Influence Diagram 1 of 5 ![HwkQ1_influence_diagram_Page_1.png](data:image/png;base64,...)

# %% [markdown]
# Influence Diagram 2 of 5 ![HwkQ1_influence_diagram_Page_2.png](data:image/png;base64,...)

# %% [markdown]
# Influence Diagram 3 of 5
#
# ![HwkQ1_influence_diagram_Page_3.png](data:image/png;base64,...)

# %% [markdown]
# Influence Diagram 4 of 5
#
# ![HwkQ1_influence_diagram_Page_4.png](data:image/png;base64,...)

# %% [markdown]
# Influence Diagram 4 of 5
#
# ![HwkQ1_influence_diagram_Page_5.png](data:image/png;base64,...)

# %% [markdown]
# #Question #2
#
# ![HwkQ2UmbrellaA.png](data:image/png;base64,...)
