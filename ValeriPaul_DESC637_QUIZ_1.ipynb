# %% [markdown]
# <a href="https://colab.research.google.com/github/vapaul10/Business-Multiple-Attributes/blob/Quiz1_Week5/ValeriPaul_DESC637_QUIZ_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quiz 1 Question 1
#
# Explain in your own words why it is important in some situations to consider future decisions as well as the immediate decision at hand. Can you give an example from your own experience of an occasion in which you had to make a decision while explicitly anticipating a subsequent decision? How did the immediate decision affect the subsequent one?

# %%
### Future decisions must always be considered at the same time current
### decisions are being made.  Even in situation when urgent business 
### decisions are being made it is important to consider future decision 
### with benchmarks and placeholders. In some cases there is uncertainty 
### in the future with not knowing the exact specific outcomes.  For example, 
### I work for a science publishing company that serves schools in grades K-12. 
### The states require new curriculum in science every 8-10 years on average. 
### My publishing company wants schools to purchase their curriculum. 
### The uncertain events include is when schools will be purchasing and
### the criteria the school decision-makers will use.  
### The outcome is the investment our company must make is 
### to “modify our curriculum” in order for it to be “considered” by a school 
### for purchase within the next year. The outcome is the value of the
### investment within a range which is next year’s forecasted number 
### which can be from $0 to $10 million, let’s say.
 
### The subsequent decisions, of course included investment, to modify 
### our company’s curriculum, which is print and digital to meet a
### state’s curriculum criteria.  Time & resources involved in this decision 
### become top priority and the subsequent factors related to it 
### are also considered, like hiring and more. 
### Additionally, if the company decides not to  “modify the curriculum” to 
### meet the state’s criteria in order for schools to purchase it, 
### the company executives must seek alternatives to gain income from
### other sources. 

### This initial or current choice will eliminate a future valuable option
### from the outcomes related to the investment required to prepare 
### curriculum for future purchase by any school within the state 
### with different criteria that our current published curriculum.

# %% [markdown]
# ![Q1Q1_decisiontree.png](data:image/png;base64,...)

# %% [markdown]
# #Quiz 1 Question 2
#
# Sometimes broadening the decision context can change the planning horizon. For example, many companies face specific technical problems. Framed in a narrow decision context, the question is how to solve the specific problem, and a reasonable solution may be to hire a consultant. On the other hand, if the decision context is broadened to include solving related problems as well as the current one, the company might want to develop in-house expertise by hiring one or more permanent employees or training an existing employee in the required skills. What is the planning horizon in each case, and why does it change with the broader context? What objectives must be considered in the broader context that can be ignored in the narrower one?

# %% [markdown]
# ![Q1Q2_drawing.png](data:image/png;base64,...)

# %%
### The planning horizon occurs by looking forward from the time currently 
### along with the current decisions into the end of the time line. 
### There are lots of factors that will be considered.  Part of the decision 
### is to consider problems that will occur along with the isolated problems
### along the way that will not repeat set-up a reasonable horizon.  
### If more similar problems are expected it is important to adjust planning
### horizon to anticipates these occurrences. 

### For example, in my companies' plans to modify their curriculum to meet
### a state’s criteria for schools to adopt or purchase it, 
### it is important to consider hiring of additional employees 
### to meet the demands within the timeline and plan.  
### As a result, the hiring of new employees our company will have to consider 
### all the human resource law and the other consequences related to
### hiring new people, like benefits, long-term goals, performance reviews,
### training and the impact on the culture of the company at large.
### This is simple example of decisions, planning horizons and 
### the subsequent consequences and additional decisions that are required
### to make good decisions.

# %% [markdown]
# # Quiz 1 Question 3
#
# Find the net present value of a project that has cash flows of −$12,000 in Year 1, +$5,000 in Years 2 and 3, −$2,000 in Year 4, and +$6,000 in Years 5 and 6. Use an interest rate of 12%.
#
# Bonus: Find the interest rate that gives a net present value of zero.

# %%
###
###import matplotlib

###	The Net Present Value = Project
###	 -$12000 	Yr 1	=(-12000/(1.12))   -10714.29
###	  $ 5000	Yr 2	=(5000/(1.12^2))	   3985.97
###	  $ 5000	Yr 3	=(5000/(1.12^3))     3558.90
###	 -$ 2000	Yr 4		=(-2000/(1.12^4)) -1271.04
###	  $ 6000	Yr 5		=(6000/(1.12^5))	 3404.56
###	  $ 6000	Yr 6		=(6000/(1.12^6))	 3039.79
								
###   =NPV(0.12,12000,5000,5000,-2000,6000,6000)   = $2003.90
###  Bonus: Find the interest rate that gives a net present value of zero.
###	 The interest rate that gives NPV of Zero (0)
###	 =IRR(-12000,5000,5000,-2000,6000,6000,0.1)    = 19.19%
###

# %% [markdown]
# # Quiz 1 Question 4
#
# A stock market investor has $500 to spend and is considering purchasing an option contract on 1,000 shares of Apricot Computer. The shares themselves are currently selling for $28.50 per share. Apricot is involved in a lawsuit, the outcome of which will be known within a month. If the outcome is in Apricot’s favor, analysts expect Apricot’s stock price to increase by $5 per share. If the outcome is unfavorable, the price is expected to drop by $2.75 per share. The option costs $500, and owning the option would allow the investor to purchase 1,000 shares of Apricot stock for $30 per share. Thus, if the investor buys the option and Apricot prevails in the lawsuit, the investor would make an immediate profit. Aside from purchasing the option, the investor could
#   (1) do nothing and earn about 8% on his money, or
#   (2) purchase $500 worth of Apricot shares.
#
#      a) Construct cumulative risk profiles for the three alternatives, assuming Apricot has a 25% chance of winning the lawsuit. Can you draw any conclusions?
#
#      b) If the investor believes that Apricot stands a 25% chance of winning the lawsuit, should he purchase the option? What if he believes the chance is only 10%? How large does the probability have to be for the option to be worthwhile?

# %%
###
###   a.  If Apricot has a 25% chance of winning the lawsuit I recommend
###  **Buy Options**
###  Win 3500 – 500  =  3000

###Lose   -500

###  **Buy Apricot**
###  Win Share Price
###         (33.5*(17))+(15.5*(1.0067))-500= 85.10
###  Lose Share Price
###         ((25.75*(17))+(15.5*(1.0067))-500) = 46.65


###  **Invest in Money Market**
###  500*(1.0067) – 500 =  $3.33

# %% [markdown]
# ![Quiz1Question4a_only.png](data:image/png;base64,...)

# %% [markdown]
# b) How large does the probability have to be for the option to be worthwhile?

# %% [markdown]
# ![Quiz1Question4a-b_w_alternatives_Page_2.png](data:image/png;base64,...)

# %%
### The Optimal seems to be  p = 0.10

### Buy Option
### 	EMV  = (0.10*(3000) + 0.90*(-500)) = $-150

### Buy Stock 
### 	EMV  = ((0.10*85.10) + 0.90 * (-46.65))  $-33.48

### Do Nothing  
### EMV =  500*(1.0067) – 500 =  $3.33
